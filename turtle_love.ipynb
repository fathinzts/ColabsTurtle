# %% [markdown]
# Remake original code from https://www.youtube.com/watch?v=2STVF2vCx2c

# %%
# !pip3 install ColabTurtle

# %%
from ColabTurtle.Turtle import *
initializeTurtle(initial_speed=10)
pensize(2)
color("pink")
def curve():
  for i in range (200):
    right(1)
    forward(1)

left(140)
forward(111.65)
curve()

left(120)
curve()
forward(111.65)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...
